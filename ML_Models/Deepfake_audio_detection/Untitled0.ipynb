# %%
s=input('enter A String:')
if(s==s[::-1]):
  print(s,'is a palindrome.')
else:
  print(s,'is not a palindrome')
# Out:
# enter A String:RajaR
# RajaR is a palindrome.

# %%
len('hello')
# Out:
# 5

# %%
'true'.capitalize()
# Out:
# 'True'

# %%
'my Name is khan'.capitalize()
# Out:
# 'My name is khan'

# %%
string='it goes as-ringa ringa roses'   
sub='ringa'
string.find(sub,15,21)
# Out:
# -1
